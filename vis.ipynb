# %%
import numpy as np
import matplotlib.pyplot as plt
import pyvista as pv
pv.set_jupyter_backend('client')
import glob
import natsort

# %%
filepath = '/home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_100.vtu'
mesh = pv.read(filepath)

half_pipe = mesh.clip(normal='y',origin=mesh.center,invert=False)

plotter = pv.Plotter(notebook=True)  # Use notebook=False outside Jupyter
# plotter.add_mesh(mesh, style="wireframe")
plotter.add_mesh(half_pipe, scalars="Pressure", cmap="viridis")#, show_edges=True, edge_opacity=0.3)

# plotter.add_scalar_bar(title="Pressure")
plotter.camera_position = 'xz'
plotter.add_axes(interactive=True)

plotter.show()
# Out:
# Widget(value='<iframe src="http://localhost:42603/index.html?ui=P_0x7379a9143650_14&reconnect=auto" class="pyv…

# %%
def animate_result(filepath, pref, cam='xz'):
    # Get files
    vtu_files = glob.glob(filepath + pref+"_*.vtu")
    vtu_files = natsort.natsorted(vtu_files)

    # Initialize plotters
    pl_p = pv.Plotter(notebook=False,off_screen=True) # Pressure
    pl_p.open_gif(filepath + 'pressure.gif')   
    pl_u = pv.Plotter(notebook=False,off_screen=True) # U
    pl_u.open_gif(filepath + 'u.gif')   
    pl_magU = pv.Plotter(notebook=False,off_screen=True) # magU
    pl_magU.open_gif(filepath + 'magU.gif')   

    # Make and save frames to gif
    for filename in vtu_files:
        # Print timestep
        print(filename)
        
        # Clear previous frame
        pl_p.clear()  
        pl_u.clear()  
        pl_magU.clear()  

        # Read mesh
        mesh = pv.read(filename)
        
        # Get displaced mesh
        delta = mesh.point_data['Displacement']
        mesh_def = mesh.copy()
        mesh_def.points = mesh.points + delta

        # Make scalars

        # Pressure
        mesh_def['Pressure'] = mesh_def.point_data['Pressure']

        # Magnitude of velocity
        u = mesh_def.point_data['Velocity']
        magU = np.linalg.norm(u,axis=1)
        mesh_def['magU'] = magU

        # u, v, w
        mesh_def['u'] = u[:,0]
        mesh_def['v'] = u[:,1]
        mesh_def['w'] = u[:,2]

        # Clip for vizualization purposes
        half_pipe = mesh_def.clip(normal='y',origin=mesh.center,invert=False)

        # Plot

        # Pressure
        pl_p.add_mesh(half_pipe, scalars="Pressure", cmap="viridis", show_edges=False)
        pl_p.camera_position = cam
        pl_p.add_axes(interactive=True)
        pl_p.add_text(f"Time step: {filename}", font_size=10)  
        pl_p.write_frame()

        # U
        pl_u.add_mesh(half_pipe, scalars="u", cmap="viridis", show_edges=False)
        pl_u.camera_position = cam
        pl_u.add_axes(interactive=True)
        pl_u.add_text(f"Time step: {filename}", font_size=10)  
        pl_u.write_frame()

        # magU
        pl_magU.add_mesh(half_pipe, scalars="magU", cmap="viridis", show_edges=False)
        pl_magU.camera_position = cam
        pl_magU.add_axes(interactive=True)
        pl_magU.add_text(f"Time step: {filename}", font_size=10)  
        pl_magU.write_frame()

    pl_p.close()
    pl_u.close()
    pl_magU.close()

# %%
# Set paths
# data_path = '/home/dana/Documents/SimVascular/svMultiPhysics/tests/cases/fsi/pipe_3d/'
data_path = '/home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/'
pref = '4-procs/result'
save_name = 'pressure'
vtu_files = glob.glob(data_path + pref+"_*.vtu")
vtu_files = natsort.natsorted(vtu_files)

# Save animation
animate_result(data_path, pref)
# Out:
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_001.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_002.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_003.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_004.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_005.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_006.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_007.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_008.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_009.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_010.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_011.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_012.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_013.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_014.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_015.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_016.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_017.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_018.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_019.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_020.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_021.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_022.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_023.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_024.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_025.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_026.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_027.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_028.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_029.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_030.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_031.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_032.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_033.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_034.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_035.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_036.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_037.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_038.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_039.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_040.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_041.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_042.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_043.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_044.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_045.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_046.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_047.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_048.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_049.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_050.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_051.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_052.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_053.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_054.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_055.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_056.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_057.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_058.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_059.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_060.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_061.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_062.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_063.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_064.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_065.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_066.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_067.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_068.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_069.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_070.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_071.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_072.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_073.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_074.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_075.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_076.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_077.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_078.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_079.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_080.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_081.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_082.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_083.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_084.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_085.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_086.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_087.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_088.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_089.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_090.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_091.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_092.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_093.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_094.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_095.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_096.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_097.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_098.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_099.vtu
# /home/dana/Documents/SimVascular/svMultiPhysics/NoisyPipe/4-procs/result_100.vtu
